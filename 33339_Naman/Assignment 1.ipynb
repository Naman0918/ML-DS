# %%
#importing libraries
import pandas as pd 
import numpy as np

# %%
# Here we are reading the csv file 
heart = pd.read_csv('heart.csv')

# %%
heart
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
# Here we can see the size of matrix or csv
heart.shape
# Out:
# (1025, 14)

# %%
# Cheking if their is any null value present or not 
heart.isna
# Out:
# <bound method DataFrame.isna of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
#Here we are see all the data types
heart.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
#Checking th information about the columns
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
# Here we are checking how many 0s are there in columns
(heart==0).sum(axis=0)
# Out:
# age           0
# sex         312
# cp          497
# trestbps      0
# chol          0
# fbs         872
# restecg     497
# thalach       0
# exang       680
# oldpeak     329
# slope        74
# ca          578
# thal          7
# target      499
# dtype: int64

# %%
#Here we can find 0 s in rows 
(heart==0).sum(axis=1)
# Out:
# 0       4
# 1       5
# 2       5
# 3       5
# 4       4
#        ..
# 1020    3
# 1021    4
# 1022    4
# 1023    7
# 1024    4
# Length: 1025, dtype: int64

# %%
heart.iloc[:, 0].mean()
# Out:
# 54.43414634146342

# %%
#here we found the mean of ages 
heart["age"].mean()
# Out:
# 54.43414634146342

# %%
#Here we can show only specific columns 
df = heart[["age","sex","cp","trestbps","chol","fbs"]]
df
# Out:
#       age  sex  cp  trestbps  chol  fbs
# 0      52    1   0       125   212    0
# 1      53    1   0       140   203    1
# 2      70    1   0       145   174    0
# 3      61    1   0       148   203    0
# 4      62    0   0       138   294    1
# ...   ...  ...  ..       ...   ...  ...
# 1020   59    1   1       140   221    0
# 1021   60    1   0       125   258    0
# 1022   47    1   0       110   275    0
# 1023   50    0   0       110   254    0
# 1024   54    1   0       120   188    0
#
# [1025 rows x 6 columns]

# %%
# From scikit learn import the train_test_split library 
# From scikit learn library we can divide the data into training and test set 
# so that we can implement the methods on training set and apply same methods on test set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df,heart, test_size=0.25)

# %%
x_train
# Out:
#      age  sex  cp  trestbps  chol  fbs
# 500   71    0   0       112   149    0
# 920   39    1   0       118   219    0
# 994   59    1   0       110   239    0
# 630   45    1   3       110   264    0
# 166   56    1   0       132   184    0
# ..   ...  ...  ..       ...   ...  ...
# 70    59    1   0       170   326    0
# 22    45    1   0       104   208    0
# 135   58    0   0       170   225    1
# 872   64    1   3       170   227    0
# 610   43    0   0       132   341    1
#
# [768 rows x 6 columns]

# %%
y_train
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 500   71    0   0       112   149    0        1      125      0      1.6
# 920   39    1   0       118   219    0        1      140      0      1.2
# 994   59    1   0       110   239    0        0      142      1      1.2
# 630   45    1   3       110   264    0        1      132      0      1.2
# 166   56    1   0       132   184    0        0      105      1      2.1
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 70    59    1   0       170   326    0        0      140      1      3.4
# 22    45    1   0       104   208    0        0      148      1      3.0
# 135   58    0   0       170   225    1        0      146      1      2.8
# 872   64    1   3       170   227    0        0      155      0      0.6
# 610   43    0   0       132   341    1        0      136      1      3.0
#
#      slope  ca  thal  target
# 500      1   0     2       1
# 920      1   0     3       0
# ...

# %%
x_test
# Out:
#      age  sex  cp  trestbps  chol  fbs
# 896   59    1   3       178   270    0
# 805   53    1   0       142   226    0
# 651   41    1   1       120   157    0
# 1     53    1   0       140   203    1
# 864   59    1   3       160   273    0
# ..   ...  ...  ..       ...   ...  ...
# 899   59    1   0       135   234    0
# 955   62    1   2       130   231    0
# 236   49    1   2       118   149    0
# 28    56    1   2       130   256    1
# 291   58    1   0       128   259    0
#
# [257 rows x 6 columns]

# %%
y_test
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 896   59    1   3       178   270    0        0      145      0      4.2
# 805   53    1   0       142   226    0        0      111      1      0.0
# 651   41    1   1       120   157    0        1      182      0      0.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 864   59    1   3       160   273    0        0      125      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 899   59    1   0       135   234    0        1      161      0      0.5
# 955   62    1   2       130   231    0        1      146      0      1.8
# 236   49    1   2       118   149    0        0      126      0      0.8
# 28    56    1   2       130   256    1        0      142      1      0.6
# 291   58    1   0       128   259    0        0      130      1      3.0
#
#      slope  ca  thal  target
# 896      0   0     3       1
# 805      2   0     3       1
# ...

# %%
#import matplot library
import matplotlib.pyplot as plt

# %%
# here we are just plotting the points in th scattered form in the graph
plt.scatter(heart.age, heart.trestbps, label="RestBP")
plt.xlabel("Age", color='white')# giving label to x axis
plt.ylabel("trestbps",color='white')# giving label to y axis
plt.title("RestBP of People",color='white')# giving title to graph
plt.xticks(color='white')# Give white color to the ticks
plt.yticks(color='white')# Give white color to the ticks
plt.legend()
plt.show()

# %%
# data1 = [df.trestbps[df.trestbps == 'typical'].count(),df.trestbps[df.trestbps == 'asymptomatic'].count()
# ,df.trestbps[df.trestbps == 'nonanginal'].count(),df.trestbps[df.trestbps == 'nontypical'].count()]
# label1 = ['typical', 'asymptomatic', 'nonanginal', 'nontypical']
# plt.pie(data1,labels = lable1);
# plt.title("People with trestbps")
# plt.show()

# %%
#we are plotting a histogram 
plt.hist(heart.trestbps, color='BLUE')
plt.title("Max HR", color ='white')
plt.show()

# %%
import numpy as np
var = np.array([[9,5,7], [2,1,7]])
var.min(axis = 0)
# Out:
# array([2, 1, 7])
